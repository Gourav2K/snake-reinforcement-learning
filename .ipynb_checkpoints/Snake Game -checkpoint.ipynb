# %%
import subprocess
import pyautogui
from mss import mss
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
import pygetwindow as gw
import time

# %%
import random

# %%
def start_game():
    command = "start java App"  # Replace with your actual command
    subprocess.run(command, shell=True)

def focus_game_window(title):
    window = gw.getWindowsWithTitle(title)[0]
    if window != []:
        try:
            window.activate()
        except:
            window.minimize()
            window.restore()

def close_game(title):
    try:
        game_window = gw.getWindowsWithTitle(title)[0]  # Adjust the title accordingly
        if game_window:
            game_window.close()
            time.sleep(0.5)  # Give some time for the window to close
    except Exception as e:
        print(f"Error closing window: {e}")

def restart_game():
    # Press the Spacebar
    pyautogui.press('space')
    
#if game_has_ended():  # You need to implement this function
#    restart_game()

def get_window_by_exact_title(title):
    windows = gw.getWindowsWithTitle(title)
    for window in windows:
        if window.title == title:
            return window
    return None

def get_window_dimensions(title):
    window = get_window_by_exact_title(title)  # Get the window with the specified title
    if window:
        return window.left+5, window.top+40, window.left+window.width-5, window.top+window.height-5
    else:
        return None

# %%
# Example usage
dimensions = get_window_dimensions("Snake")  # Replace with your window's title
if dimensions:
    print("Window position and size:", dimensions)
else:
    print("Window not found.")
# Out:
# Window position and size: (590, 175, 1347, 926)

# %%
def capture_screen(region=None):
    with mss() as sct:
        # The screen part to capture
        monitor = region if region else sct.monitors[1]  # Default to the entire screen
        screenshot = sct.grab(monitor)
        img = np.array(screenshot)

        # Convert to a format suitable for Matplotlib (remove alpha channel)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        return img

def display_image(img):
    plt.imshow(img, aspect='auto')
    plt.show()

def analyze_game_state(img):
    text = pytesseract.image_to_string(img[:35, :200])
#     display_image(img[:35, :200])
    if "Score" in text:
        return "In Progress",text
    else:
        return "Game Over", text

def get_score_from_text(text):
    return int(text.split(':')[1].strip())

# %%
get_score_from_text("Score: 1234\n")
# Out:
# 1234

# %%
start_game()
time.sleep(2)
for i in range(10):
    img = capture_screen(dimensions)
    game_state, text = analyze_game_state(img)
    print(game_state, text)
    display_image(img)
# Out:
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0
# In Progress Score: 0

# %%
img.shape
# Out:
# (751, 757, 3)

# %%
game_state
# Out:
# 'Game Over'

# %%
start_game()
time.sleep(2)
dimensions = get_window_dimensions("Snake")  # Replace with your window's title

# %%
dimensions
# Out:
# (590, 175, 1347, 926)

# %%
def make_move(idx):
    moves = ['up', 'down', 'left', 'right']
    pyautogui.press(moves[idx])

# %%
def game_loop():
    # Start the game
    start_game()
    time.sleep(2)  # Wait for the game to open

    while True:
        window = get_window_by_exact_title('Snake')
        if window == None:
            break  # Exit the loop if no windows are found

        img = capture_screen(dimensions)
        game_state, text = analyze_game_state(img)

        if game_state == "Game Over":
            restart_game() 
   
        elif game_state == "In Progress":
            # Game-playing logic
            idx = random.randint(0,3)
            print('Move - ', str(idx))
            make_move(idx)
            score = get_score_from_text(text)
            print('Score: ' + str(score))
            display_image(img)

        else:
            # Unknown state
            print(game_state, text)

# %%
game_loop()
# Out:
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  3
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  2
# Score: 0
# Move -  3
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  3
# Score: 0
# Move -  3
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  1
# Score: 0
# Move -  3
# Score: 0
# Move -  3
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  1
# Score: 0
# Move -  2
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  1
# Score: 0
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  1
# Score: 0
# Move -  2
# Score: 0
# Move -  3
# Score: 0
# Move -  1
# Score: 0
# Move -  1
# Score: 0
# Move -  1
# Score: 0
# Move -  1
# Score: 0
# Move -  3
# Score: 0
# Move -  1
# Score: 0
# Move -  1
# Score: 0
# Move -  2
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  1
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  1
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  2
# Score: 0
# Move -  2
# Score: 0
# Move -  3
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  1
# Score: 0
# Move -  3
# Score: 0
# Move -  1
# Score: 0
# Move -  2
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  1
# Score: 0
# Move -  2
# Score: 0
# Move -  1
# Score: 0
# Move -  1
# Score: 0
# Move -  3
# Score: 0
# Move -  1
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  3
# Score: 0
# Move -  1
# Score: 0
# Move -  0
# Score: 0
# Move -  1
# Score: 0
# Move -  0
# Score: 0
# Move -  0
# Score: 0
# Move -  2
# Score: 0
# Move -  1
# Score: 0
# Move -  1
# Score: 0
# Move -  3
# Score: 0
# Move -  2
# Score: 0
# Move -  1
# Score: 0

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class DQN(nn.Module):
    def __init__(self, h, w, outputs):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=5, stride=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.bn3 = nn.BatchNorm2d(32)

        def conv2d_size_out(size, kernel_size=5, stride=2):
            return (size - (kernel_size - 1) - 1) // stride + 1

        convw = conv2d_size_out(conv2d_size_out(conv2d_size_out(w)))
        convh = conv2d_size_out(conv2d_size_out(conv2d_size_out(h)))
        linear_input_size = convw * convh * 32
        self.head = nn.Linear(linear_input_size, outputs)

    def forward(self, x):
        x = x.to(torch.float32) / 255  # Normalize pixel values
        x = nn.functional.relu(self.bn1(self.conv1(x)))
        x = nn.functional.relu(self.bn2(self.conv2(x)))
        x = nn.functional.relu(self.bn3(self.conv3(x)))
        return self.head(x.view(x.size(0), -1))

# %%
import cv2
import numpy as np

def preprocess_image(dimensions, height, width):
    image = capture_screen(dimensions)
    image = cv2.resize(image, (width, height))
    image = np.expand_dims(image, axis=0)  # Add channel dimension
    image = image / 255.0
    
    # Convert to PyTorch tensor and add batch dimension (NCHW format)
    return torch.from_numpy(image).unsqueeze(0).float()

# %%
import random
from collections import namedtuple, deque

Experience = namedtuple('Experience', ('state', 'action', 'next_state', 'reward', 'done'))

class ReplayMemory(object):
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Experience(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
def select_action(state, policy_net, epsilon):
    sample = random.random()
    if sample > epsilon:
        with torch.no_grad():
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(num_actions)]], dtype=torch.long)

# %%
def optimize_model():
    if len(replay_memory) < batch_size:
        return

    transitions = replay_memory.sample(batch_size)
    batch = Experience(*zip(*transitions))

    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(batch_size)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()

    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
# Check if a GPU is available and use it; otherwise, use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
torch.zeros(1).cuda()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 torch.zeros(1).cuda()
#
# File C:\anaconda3\envs\tensorflow_env\lib\site-packages\torch\cuda\__init__.py:166, in _lazy_init()
#     162     raise RuntimeError(
#     163         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     164         "multiprocessing, you must use the 'spawn' start method")
#     165 if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 166     raise AssertionError("Torch not compiled with CUDA enabled")
#     167 if _cudart is None:
#     168     raise AssertionError(
#     169         "libcudart functions unavailable. It looks like you have a broken build?")
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
# Define the dimensions of the preprocessed images
image_height = 300
image_width = 300

# Define the number of actions
num_actions = 4

# Create the DQN networks
policy_net = DQN(image_height, image_width, num_actions).to(device)
target_net = DQN(image_height, image_width, num_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.RMSprop(policy_net.parameters())
replay_memory = ReplayMemory(10000)

for episode in range(num_episodes):
    state = preprocess_image(get_initial_state())
    for t in count():
        action = select_action(state, policy_net, EPSILON)
        next_state, reward, done = step_game(action.item())
        next_state = preprocess_image(next_state) if not done else None
        replay_memory.push(state, action, next_state, torch.tensor([reward]), torch.tensor([done]))

        state = next_state
        optimize_model()
        if done:
            break

    # Update the target network
    if episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 9
#       6 num_actions = 4
#       8 # Create the DQN networks
# ----> 9 policy_net = DQN(image_height, image_width, num_actions).to(device)
#      10 target_net = DQN(image_height, image_width, num_actions).to(device)
#      11 target_net.load_state_dict(policy_net.state_dict())
#
# NameError: name 'device' is not defined
